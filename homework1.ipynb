# %% [markdown]
# <a href="https://colab.research.google.com/github/in3xes/docs/blob/master/homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statistics as stat
from tabulate import tabulate
import numpy as np
from numpy import *
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train_df = pd.read_csv('/content/test.csv')
test_df = pd.read_csv('/content/test.csv')
train_df.head(10)
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
# 5          897       3  ...   NaN        S
# 6          898       3  ...   NaN        Q
# 7          899       2  ...   NaN        S
# 8          900       3  ...   NaN        C
# 9          901       3  ...   NaN        S
#
# [10 rows x 11 columns]

# %% [markdown]
# **Question 7:**

# %%
pid = train_df["PassengerId"].tolist()
sur = train_df["Survived"].tolist()
pcls = train_df["Pclass"].tolist()
age = train_df["Age"].fillna(0).tolist()
sib = train_df["SibSp"].tolist()
parch = train_df["Parch"].tolist()
fare = train_df["Fare"].tolist()

pid_list = ["PassengerId", len(pid), stat.mean(pid), stat.pstdev(pid), min(pid), np.percentile(pid, 25), np.percentile(pid, 50), np.percentile(pid, 75), max(pid)]
sur_list = ["Survived", len(sur), stat.mean(sur), stat.pstdev(sur), min(sur), np.percentile(sur, 25), np.percentile(sur, 50), np.percentile(sur, 75), max(sur)]
pcls_list = ["Pclass", len(pcls), stat.mean(pcls), stat.pstdev(pcls), min(pcls), np.percentile(pcls, 25), np.percentile(pcls, 50), np.percentile(pcls, 75), max(pcls)]
age_list = ["Age", len(age), stat.mean(age), stat.pstdev(age), min(age), np.percentile(age, 25), np.percentile(age, 50), np.percentile(age, 75), max(age)]
sib_list = ["SibSp", len(sib), stat.mean(sib), stat.pstdev(sib), min(sib), np.percentile(sib, 25), np.percentile(sib, 50), np.percentile(sib, 75), max(sib)]
parch_list = ["Parch", len(parch), stat.mean(parch), stat.pstdev(parch), min(parch), np.percentile(parch, 25), np.percentile(parch, 50), np.percentile(parch, 75), max(parch)]
fare_list = ["Fare", len(fare), stat.mean(fare), stat.pstdev(fare), min(fare), np.percentile(fare, 25), np.percentile(fare, 50), np.percentile(fare, 75), max(fare)]

print(tabulate([pid_list, sur_list, pcls_list, age_list, sib_list, parch_list, fare_list],
               headers=["Feature", "Length", "Mean", "Std", "Min", "25%", "50%", "75%", "Max"], tablefmt='orgtbl'))
# Out:
# | Feature     |   Length |       Mean |        Std |   Min |      25% |      50% |   75% |     Max |
# |-------------+----------+------------+------------+-------+----------+----------+-------+---------|
# | PassengerId |      891 | 446        | 257.209    |     1 | 223.5    | 446      | 668.5 | 891     |
# | Survived    |      891 |   0.383838 |   0.486319 |     0 |   0      |   0      |   1   |   1     |
# | Pclass      |      891 |   2.30864  |   0.835602 |     1 |   2      |   3      |   3   |   3     |
# | Age         |      891 |  23.7993   |  17.5862   |     0 |   6      |  24      |  35   |  80     |
# | SibSp       |      891 |   0.523008 |   1.10212  |     0 |   0      |   0      |   1   |   8     |
# | Parch       |      891 |   0.381594 |   0.805605 |     0 |   0      |   0      |   0   |   6     |
# | Fare        |      891 |  32.2042   |  49.6655   |     0 |   7.9104 |  14.4542 |  31   | 512.329 |

# %%
pid = test_df["PassengerId"].tolist()
pcls = test_df["Pclass"].tolist()
age = test_df["Age"].fillna(0).tolist()
sib = test_df["SibSp"].tolist()
parch = test_df["Parch"].tolist()
fare = test_df["Fare"].fillna(0).tolist()

pid_list = ["PassengerId", len(pid), stat.mean(pid), stat.pstdev(pid), min(pid), np.percentile(pid, 25), np.percentile(pid, 50), np.percentile(pid, 75), max(pid)]
pcls_list = ["Pclass", len(pcls), stat.mean(pcls), stat.pstdev(pcls), min(pcls), np.percentile(pcls, 25), np.percentile(pcls, 50), np.percentile(pcls, 75), max(pcls)]
age_list = ["Age", len(age), stat.mean(age), stat.pstdev(age), min(age), np.percentile(age, 25), np.percentile(age, 50), np.percentile(age, 75), max(age)]
sib_list = ["SibSp", len(sib), stat.mean(sib), stat.pstdev(sib), min(sib), np.percentile(sib, 25), np.percentile(sib, 50), np.percentile(sib, 75), max(sib)]
parch_list = ["Parch", len(parch), stat.mean(parch), stat.pstdev(parch), min(parch), np.percentile(parch, 25), np.percentile(parch, 50), np.percentile(parch, 75), max(parch)]
fare_list = ["Fare", len(fare), stat.mean(fare), stat.pstdev(fare), min(fare), np.percentile(fare, 25), np.percentile(fare, 50), np.percentile(fare, 75), max(fare)]

print(tabulate([pid_list, pcls_list, age_list, sib_list, parch_list, fare_list],
               headers=["Feature", "Length", "Mean", "Std", "Min", "25%", "50%", "75%", "Max"], tablefmt='orgtbl'))
# Out:
# | Feature     |   Length |        Mean |        Std |   Min |      25% |       50% |       75% |      Max |
# |-------------+----------+-------------+------------+-------+----------+-----------+-----------+----------|
# | PassengerId |      418 | 1100.5      | 120.666    |   892 | 996.25   | 1100.5    | 1204.75   | 1309     |
# | Pclass      |      418 |    2.26555  |   0.84083  |     1 |   1      |    3      |    3      |    3     |
# | Age         |      418 |   24.0443   |  17.5785   |     0 |   9      |   24      |   35.75   |   76     |
# | SibSp       |      418 |    0.447368 |   0.895686 |     0 |   0      |    0      |    1      |    8     |
# | Parch       |      418 |    0.392344 |   0.980254 |     0 |   0      |    0      |    0      |    9     |
# | Fare        |      418 |   35.542    |  55.8008   |     0 |   7.8958 |   14.4542 |   31.4719 |  512.329 |

# %% [markdown]
# **Question 8:**

# %%
train_df.describe(include=['O'])
# Out:
#                        Name   Sex    Ticket    Cabin Embarked
# count                   891   891       891      204      889
# unique                  891     2       681      147        3
# top     Cacic, Miss. Marija  male  CA. 2343  B96 B98        S
# freq                      1   577         7        4      644

# %%
test_df.describe(include=['O'])
# Out:
#                         Name   Sex    Ticket            Cabin Embarked
# count                    418   418       418               91      418
# unique                   418     2       363               76        3
# top     Duquemin, Mr. Joseph  male  PC 17608  B57 B59 B63 B66        S
# freq                       1   266         5                3      270

# %% [markdown]
# **Question 9:**

# %%
pcls = train_df["Pclass"].tolist()
sur = train_df["Survived"].tolist()

sur_1 = 0
sur_1_count = 0
sur_2 = 0
sur_2_count = 0
sur_3 = 0
sur_3_count = 0


for x in range(0, len(pcls)):
  if pcls[x] == 1:
    sur_1_count += 1
    if sur[x] == 1:
      sur_1 += 1
  elif pcls[x] == 2:
    sur_2_count += 1
    if sur[x] == 1:
      sur_2 += 1
  elif pcls[x] == 3:
    sur_3_count += 1
    if sur[x] == 1:
      sur_3 += 1

print("Survival for Pclass 1 : ", sur_1/sur_1_count)
print("Survival for Pclass 2 : ", sur_2/sur_2_count)
print("Survival for Pclass 3 : ", sur_3/sur_3_count)
# Out:
# Survival for Pclass 1 :  0.6296296296296297
# Survival for Pclass 2 :  0.47282608695652173
# Survival for Pclass 3 :  0.24236252545824846

# %% [markdown]
# **Question 10:**

# %%
sex = train_df["Sex"].tolist()
sur = train_df["Survived"].tolist()

sur_w = 0
sur_w_count = 0

sur_m = 0
sur_m_count = 0

for x in range(0, len(sex)):
  if sex[x] == "female":
    sur_w_count += 1
    if sur[x] == 1:
      sur_w += 1
  else:
    sur_m_count += 1
    if sur[x] == 1:
      sur_m += 1

print("Survival for women : ", sur_w/sur_w_count)
print("Survival for men : ", sur_m/sur_m_count)
# Out:
# Survival for women :  0.7420382165605095
# Survival for men :  0.18890814558058924

# %% [markdown]
# **Question 11:**

# %%
age = train_df["Age"].fillna(-1).tolist()
sur = train_df["Survived"].tolist()

d = []
d_d = []

for x in range(0, len(age)):
  if age[x] == -1:
    continue
  if sur[x] == 1:
    d.append(age[x])
  else:
    d_d.append(age[x])

bins = np.arange(0, 100, 5)
plt.xlim([0, max(d)+5])
plt.hist(d, bins=bins)
plt.title("Survival = 1")
plt.xlabel("Age")
plt.ylabel("Count")
plt.yticks(np.arange(0, 100, step=20))
# Out:
# ([<matplotlib.axis.YTick at 0x7f3ace245278>,
# ...
#  <a list of 5 Text major ticklabel objects>)

# %%
bins = np.arange(0, 100, 5)
plt.xlim([0, max(d_d)+5])
plt.hist(d_d, bins=bins)
plt.title("Survival = 0")
plt.xlabel("Age")
plt.ylabel("Count")
plt.yticks(np.arange(0, 100, step=20))
# Out:
# ([<matplotlib.axis.YTick at 0x7f3acd2cf6d8>,
# ...
#  <a list of 5 Text major ticklabel objects>)

# %% [markdown]
# **Question 12:**

# %%
pcls = train_df["Pclass"].tolist()
sur = train_df["Survived"].tolist()
age = train_df["Age"].fillna(-1).tolist()

c_1 = []
c_1_d = []
c_2 = []
c_2_d = []
c_3 = []
c_3_d = []

for x in range(0, len(pcls)):
  if age[x] == -1:
    continue
  if pcls[x] == 1:
    if sur[x] == 1:
      c_1.append(age[x])
    else:
      c_1_d.append(age[x])
  elif pcls[x] == 2:
    if sur[x] == 1:
      c_2.append(age[x])
    else:
      c_2_d.append(age[x])
  elif pcls[x] == 3:
    if sur[x] == 1:
      c_3.append(age[x])
    else:
      c_3_d.append(age[x])

fig, ax = plt.subplots(nrows=3, ncols=2)
fig.tight_layout(pad=3.0)
fig.set_figheight(8)
fig.set_figwidth(8)
ax = ax.flatten()

ax[0].hist(c_1, bins=bins)
ax[0].set_title("Survived = 1, Plcass = 1")
ax[0].set_xlabel("Age")
ax[0].set_ylabel("Count")
ax[0].set_yticks(np.arange(0, 60, step=20))
ax[0].set_ylim(0, 60)


ax[1].hist(c_1_d, bins=bins)
ax[1].set_title("Survived = 0, Pclass = 1")
ax[1].set_xlabel("Age")
ax[1].set_ylabel("Count")
ax[1].set_yticks(np.arange(0, 60, step=20))
ax[1].set_ylim(0, 60)

ax[2].hist(c_2, bins=bins)
ax[2].set_title("Survived = 1, Pclass = 2")
ax[2].set_xlabel("Age")
ax[2].set_ylabel("Count")
ax[2].set_yticks(np.arange(0, 60, step=20))
ax[2].set_ylim(0, 60)


ax[3].hist(c_2_d, bins=bins)
ax[3].set_title("Survived = 0, Pclass = 2")
ax[3].set_xlabel("Age")
ax[3].set_ylabel("Count")
ax[3].set_yticks(np.arange(0, 60, step=20))
ax[3].set_ylim(0, 60)

ax[4].hist(c_3, bins=bins)
ax[4].set_title("Survived = 1, Pclass = 3")
ax[4].set_xlabel("Age")
ax[4].set_ylabel("Count")
ax[4].set_yticks(np.arange(0, 60, step=20))
ax[4].set_ylim(0, 60)

ax[5].hist(c_3_d, bins=bins)
ax[5].set_title("Survived = 0, Pclass = 2")
ax[5].set_xlabel("Age")
ax[5].set_ylabel("Count")
ax[5].set_yticks(np.arange(0, 60, step=20))
ax[5].set_ylim(0, 60)

plt.xlim([0, max(d)+5])

plt.show()

# %% [markdown]
# **Question 13:**

# %%
pcls = train_df["Embarked"].tolist()
sur = train_df["Survived"].tolist()
age = train_df["Fare"].fillna(-1).tolist()

c_1 = []
c_1_d = []
c_2 = []
c_2_d = []
c_3 = []
c_3_d = []

for x in range(0, len(pcls)):
  if age[x] == -1:
    continue
  if pcls[x] == 1:
    if sur[x] == 1:
      c_1.append(age[x])
    else:
      c_1_d.append(age[x])
  elif pcls[x] == 2:
    if sur[x] == 1:
      c_2.append(age[x])
    else:
      c_2_d.append(age[x])
  elif pcls[x] == 3:
    if sur[x] == 1:
      c_3.append(age[x])
    else:
      c_3_d.append(age[x])

fig, ax = plt.subplots(nrows=3, ncols=2)
fig.tight_layout(pad=3.0)
fig.set_figheight(8)
fig.set_figwidth(8)
ax = ax.flatten()

ax[0].hist(c_1, bins=bins)
ax[0].set_title("Survived = 1, Plcass = 1")
ax[0].set_xlabel("Age")
ax[0].set_ylabel("Count")
ax[0].set_yticks(np.arange(0, 60, step=20))
ax[0].set_ylim(0, 60)


ax[1].hist(c_1_d, bins=bins)
ax[1].set_title("Survived = 0, Pclass = 1")
ax[1].set_xlabel("Age")
ax[1].set_ylabel("Count")
ax[1].set_yticks(np.arange(0, 60, step=20))
ax[1].set_ylim(0, 60)

ax[2].hist(c_2, bins=bins)
ax[2].set_title("Survived = 1, Pclass = 2")
ax[2].set_xlabel("Age")
ax[2].set_ylabel("Count")
ax[2].set_yticks(np.arange(0, 60, step=20))
ax[2].set_ylim(0, 60)


ax[3].hist(c_2_d, bins=bins)
ax[3].set_title("Survived = 0, Pclass = 2")
ax[3].set_xlabel("Age")
ax[3].set_ylabel("Count")
ax[3].set_yticks(np.arange(0, 60, step=20))
ax[3].set_ylim(0, 60)

ax[4].hist(c_3, bins=bins)
ax[4].set_title("Survived = 1, Pclass = 3")
ax[4].set_xlabel("Age")
ax[4].set_ylabel("Count")
ax[4].set_yticks(np.arange(0, 60, step=20))
ax[4].set_ylim(0, 60)

ax[5].hist(c_3_d, bins=bins)
ax[5].set_title("Survived = 0, Pclass = 2")
ax[5].set_xlabel("Age")
ax[5].set_ylabel("Count")
ax[5].set_yticks(np.arange(0, 60, step=20))
ax[5].set_ylim(0, 60)

plt.xlim([0, max(d)+5])

plt.show()

# %% [markdown]
# **Question 14:**

# %%
print("Total tickets: ", len(train_df["Ticket"]))
print("Unique tickets", len(set(train_df["Ticket"])))

print("Unique tickets ratio : ", len(set(train_df["Ticket"]))/len(train_df["Ticket"]))
# Out:
# Total tickets:  891
# Unique tickets 681
# Unique tickets ratio :  0.7643097643097643

# %% [markdown]
# **Question 15:**

# %%
cabin_train = train_df["Cabin"].tolist()
c_tr_len = len(cabin_train)
c_tr_null_count = cabin_train.count(nan)

print(c_tr_len, c_tr_null_count)


cabin_test = test_df["Cabin"].tolist()
c_ts_len = len(cabin_test)
c_ts_null_count = cabin_test.count(nan)

print(c_ts_len, c_ts_null_count)


print(c_tr_len + c_ts_len, c_tr_null_count + c_ts_null_count)
# Out:
# 891 687
# 418 327
# 1309 1014

# %% [markdown]
# **Question 16:**

# %%
new_train_df = train_df.copy(deep=True)
new_test_df = test_df.copy(deep=True)

new_train_df["Sex"] = new_train_df["Sex"].replace("female", 1)
new_train_df["Sex"] = new_train_df["Sex"].replace("male", 0)

new_test_df["Sex"] = new_test_df["Sex"].replace("female", 1)
new_test_df["Sex"] = new_test_df["Sex"].replace("male", 0)

new_train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare  Cabin  Embarked
# 0            1         0       3  ...   7.2500    NaN         S
# 1            2         1       1  ...  71.2833    C85         C
# 2            3         1       3  ...   7.9250    NaN         S
# 3            4         1       1  ...  53.1000   C123         S
# 4            5         0       3  ...   8.0500    NaN         S
# 5            6         0       3  ...   8.4583    NaN         Q
# 6            7         0       1  ...  51.8625    E46         S
# 7            8         0       3  ...  21.0750    NaN         S
# 8            9         1       3  ...  11.1333    NaN         S
# 9           10         1       2  ...  30.0708    NaN         C
#
# [10 rows x 12 columns]

# %% [markdown]
# **Question 17:**

# %%
from random import uniform

train_std = train_df['Age'].std()
train_median = train_df['Age'].median()

train_df["Age"] = train_df["Age"].fillna(uniform(train_std, train_median))


test_std = test_df['Age'].std()
test_median = test_df['Age'].median()

test_df["Age"] = test_df["Age"].fillna(uniform(test_std, test_median))

train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
# 8            9         1       3  ...  11.1333   NaN         S
# 9           10         1       2  ...  30.0708   NaN         C
#
# [10 rows x 12 columns]

# %% [markdown]
# **Question 18:**

# %%
import collections

train_embarked = train_df["Embarked"].tolist()
train_counter=collections.Counter(train_embarked)
print("Most common embarked for train:", train_counter.most_common(1)[0][0])

train_df["Embarked"] = train_df["Embarked"].fillna(counter.most_common(1)[0][0])

test_embarked = test_df["Embarked"].tolist()
test_counter=collections.Counter(test_embarked)
print("Most common embarked for test:", test_counter.most_common(1)[0][0])

test_df["Embarked"] = test_df["Embarked"].fillna(test_counter.most_common(1)[0][0])

train_df.head(10)
# Out:
# Most common embarked for train: S
# Most common embarked for test: S
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
# 8            9         1       3  ...  11.1333   NaN         S
# 9           10         1       2  ...  30.0708   NaN         C
#
# [10 rows x 12 columns]

# %% [markdown]
# **Question 19:**

# %%
train_df["Fare"] = train_df["Fare"].fillna(train_df['Fare'].mode()[0])

test_df["Fare"] = test_df["Fare"].fillna(test_df['Fare'].mode()[0])

train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
# 8            9         1       3  ...  11.1333   NaN         S
# 9           10         1       2  ...  30.0708   NaN         C
#
# [10 rows x 12 columns]

# %% [markdown]
# **Question 20:**
